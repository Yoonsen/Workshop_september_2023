# %%
import dhlab as dh
import pandas as pd

# %%
c = dh.Corpus(doctype="kudos", limit = 50000).frame

# %%
c.loc[c.fillna('').publisher.str.contains("kultur", case=False)].to_csv('kudos.csv')

# %%
kudos = c.loc[c.fillna('').publisher.str.contains("kultur", case=False)]

# %%
kudos
# Out:
#          dhlabid                            urn  \
# 0      700004382  URN:NBN:no-nb_dhlab_700004382
# 1      700025245  URN:NBN:no-nb_dhlab_700025245
# 14     700026104  URN:NBN:no-nb_dhlab_700026104
# 17     700013124  URN:NBN:no-nb_dhlab_700013124
# 19     700011615  URN:NBN:no-nb_dhlab_700011615
# ...          ...                            ...
# 31536  700019853  URN:NBN:no-nb_dhlab_700019853
# 31550  700021572  URN:NBN:no-nb_dhlab_700021572
# 31567  700012795  URN:NBN:no-nb_dhlab_700012795
# 31579  700023088  URN:NBN:no-nb_dhlab_700023088
# 31580  700006911  URN:NBN:no-nb_dhlab_700006911
#
#                                                    title   author oaiid  \
# 0                               Tildelingsbrev ( . pdf )
# 1      Kartlegging av kunst- og kultursektorens arbei...  Rambøll
# 14                                        Tildelingsbrev
# 17     Nasjonal plan for produksjon og formidling av ...
# 19                              Tildelingsbrev ( . pdf )
# ...                                                  ...      ...   ...
# 31536  Prop . 6 L ( 2011–2012 ) : Endringar i lov om ...
# 31550                                         Årsrapport
# 31567                          Mandat for interimsstyret
# 31579  Ot.prp . nr. 49 ( 2001-2002 ) : Om lov om endr...
# 31580                                     Tildelingsbrev
#
#       sesamid isbn10 city            timestamp  year  \
# 0                          2020-03-02 00:00:00  2020
# 1                          2022-01-01 17:14:14  2022
# 14                         2022-12-23 00:00:00  2022
# 17                         2002-04-24 00:00:00  2002
# 19                         2013-03-20 00:00:00  2013
# ...       ...    ...  ...                  ...   ...
# 31536                      2011-11-04 11:45:00  2011
# 31550                      2022-03-03 00:00:00  2022
# 31567                      2020-09-02 00:00:00  2020
# 31579                      2002-03-15 09:19:54  2002
# 31580                      2018-01-10 00:00:00  2018
#
#                                                publisher language subjects  \
# 0      Kulturdepartementet / Kultur- og likestillings...       no
# 1      Norsk kulturråd / ABM-utvikling - Statens sent...       no
# 14     Nærings- og fiskeridepartementet / Ministry of...       no
# 17     Kulturdepartementet / Kultur- og likestillings...       no
# 19     Kulturdepartementet / Kultur- og likestillings...       no
# ...                                                  ...      ...      ...
# 31536  Kulturdepartementet / Kultur- og likestillings...       nn
# 31550  Design og arkitektur Norge ( DOGA ) / Nærings-...       en
# 31567  Nærings- og fiskeridepartementet / Ministry of...       no
# 31579  Barne- og familiedepartementet / Barne- og lik...       nn
# 31580  Nærings- og fiskeridepartementet / Ministry of...       no
#
#       ddc                       genre    literaryform doctype ocr_creator  \
# 0                      Tildelingsbrev  Tildelingsbrev   kudos       kudos
# 1                         Kartlegging                   kudos       kudos
# 14                     Tildelingsbrev  Tildelingsbrev   kudos       kudos
# 17                      Ukategorisert   Plan/strategi   kudos       kudos
# 19                     Tildelingsbrev  Tildelingsbrev   kudos       kudos
# ...    ..                         ...             ...     ...         ...
# 31536      Proposisjon til Stortinget     Proposisjon   kudos       kudos
# 31550                      Årsrapport      Årsrapport   kudos       kudos
# 31567                   Ukategorisert    uspesifisert   kudos       kudos
# 31579      Proposisjon til Stortinget     Proposisjon   kudos       kudos
# 31580                  Tildelingsbrev  Tildelingsbrev   kudos       kudos
#
#              ocr_timestamp
# 0      2022-06-08 22:58:24
# 1      2022-10-09 17:14:14
# 14     2023-01-16 01:01:11
# 17     2022-10-06 14:08:02
# 19     2022-06-08 22:45:09
# ...                    ...
# 31536  2023-02-01 11:49:37
# 31550  2022-06-08 23:25:56
# 31567  2022-10-06 14:08:02
# 31579  2022-10-24 11:01:38
# 31580  2022-06-08 22:13:18
#
# [2243 rows x 19 columns]

# %%
a = pd.read_csv("barn.csv", index_col = 0)

# %%
k = pd.read_csv("kudos.csv", index_col = 0)

# %%
a.columns
# Out:
# Index(['urn', 'dhlabid', 'title', 'authors', 'oaiid', 'sesamid', 'isbn10',
#        'city', 'timestamp', 'year', 'publisher', 'langs', 'subjects', 'ddc',
#        'genres', 'literaryform', 'doctype', 'ocr_creator', 'ocr_timestamp'],
#       dtype='object')

# %%
k.columns = ['dhlabid', 'urn', 'title', 'authors', 'oaiid', 'sesamid', 'isbn10',
       'city', 'timestamp', 'year', 'publisher', 'langs', 'subjects', 'ddc',
       'genre', 'literaryform', 'doctype', 'ocr_creator', 'ocr_timestamp']

# %%
k.to_csv('kudos.csv')
