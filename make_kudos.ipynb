# %%
import dhlab as dh
import pandas as pd

# %%
c = dh.Corpus(doctype="kudos", limit = 50000).frame

# %%
c.loc[c.fillna('').publisher.str.contains("kultur", case=False)].to_csv('kudos.csv')

# %%
kudos = c.loc[c.fillna('').publisher.str.contains("kultur", case=False)]

# %%
kudos
# Out:
#          dhlabid                            urn  \
# 24     700016384  URN:NBN:no-nb_dhlab_700016384
# 55     700021605  URN:NBN:no-nb_dhlab_700021605
# 56     700013863  URN:NBN:no-nb_dhlab_700013863
# 60     700010801  URN:NBN:no-nb_dhlab_700010801
# 76     700018183  URN:NBN:no-nb_dhlab_700018183
# ...          ...                            ...
# 31509  700019997  URN:NBN:no-nb_dhlab_700019997
# 31531  700009579  URN:NBN:no-nb_dhlab_700009579
# 31545  700012114  URN:NBN:no-nb_dhlab_700012114
# 31561  700018037  URN:NBN:no-nb_dhlab_700018037
# 31569  700025970  URN:NBN:no-nb_dhlab_700025970
#
#                                                    title  \
# 24     Tillegg til tildelingsbrev for 2020 - garantio...
# 55                                          Oppdragsbrev
# 56     Brudd på anskaffelsesregelverket og mulige års...
# 60                      Kulturminnefondets samfunnsnytte
# 76     Meld . St . 20 ( 2016–2017 ) : Pliktsystemet f...
# ...

# %%
a = pd.read_csv("barn.csv", index_col = 0)

# %%
k = pd.read_csv("kudos.csv", index_col = 0)

# %%
a.columns
# Out:
# Index(['urn', 'dhlabid', 'title', 'authors', 'oaiid', 'sesamid', 'isbn10',
#        'city', 'timestamp', 'year', 'publisher', 'langs', 'subjects', 'ddc',
#        'genres', 'literaryform', 'doctype', 'ocr_creator', 'ocr_timestamp'],
#       dtype='object')

# %%
k.columns = ['dhlabid', 'urn', 'title', 'authors', 'oaiid', 'sesamid', 'isbn10',
       'city', 'timestamp', 'year', 'publisher', 'langs', 'subjects', 'ddc',
       'genre', 'literaryform', 'doctype', 'ocr_creator', 'ocr_timestamp']

# %%
k.to_csv('kudos.csv')

# %%
c.loc[c.literaryform.str.contains('Meld')].sort_values(by='timestamp')
# Out:
#          dhlabid                            urn  \
# 16655  700024641  URN:NBN:no-nb_dhlab_700024641
# 11711  700024623  URN:NBN:no-nb_dhlab_700024623
# 21654  700024591  URN:NBN:no-nb_dhlab_700024591
# 16730  700024589  URN:NBN:no-nb_dhlab_700024589
# 26164  700024561  URN:NBN:no-nb_dhlab_700024561
# ...          ...                            ...
# 12334  700127429  URN:NBN:no-nb_dhlab_700127429
# 23684  700127428  URN:NBN:no-nb_dhlab_700127428
# 20459  700127689  URN:NBN:no-nb_dhlab_700127689
# 5501   700127690  URN:NBN:no-nb_dhlab_700127690
# 17466  700132372  URN:NBN:no-nb_dhlab_700132372
#
#                                                    title authors oaiid  \
# 16655  Meld . St . 14 ( 1995–1996 ) : Om kristendomsk...
# 11711  Meld . St . 1 ( 1996–1997 ) : Nasjonalbudsjett...
# 21654  Meld . St . 16 ( 1996–1997 ) : Narkotikapoliti...
# 16730  St meld nr 22 ( 1996–97 ) : Om lærlingsituasjonen
# 26164  St.meld . nr. 6 ( 1998-99 ) : Embetsutnemninga...
# ...
