 'St.meld. nr. 28 (2004-2005) Om evaluering av maksimalpris i barnehager',
 'St.meld. nr. 20 (2004-2005) Vilje til forskning',
 'St.meld. nr. 030 (2003-2004) Kultur for læring',
 'St.meld. nr. 28 (2003-2004) Om søskenmoderasjon i foreldrebetalingen m.m.',
 'St.meld. nr. 14 (2003-2004) Om opplæringstilbod for hørselshemma',
 'St.meld. nr. 12 (2003-2004) Om modernisering av Statens lånekasse for utdanning',
 'St.meld. nr. 39 (2002-2003) «Ei blot til Lyst»',
 'St.meld. nr. 33 (2002-2003) Om ressurssituasjonen i grunnopplæringen m.m.',
 'St.meld. nr. 24 (2002-2003) Barnehagetilbud til alle - økonomi, mangfold og valgfrihet',
 'St.meld. nr. 21 (2002-2003) Kilder til kunnskap',
 'St.meld. nr. 34 (2001-2002) Kvalitetsreformen Om høyere samisk utdanning og forskning',
 'St.meld. nr. 18 (2001-2002) Kvalitetsreformen Om høyere kunstutdanning',
 'St.meld. nr. 16 (2001-2002) Kvalitetsreformen Om ny lærerutdanning Mangfoldig - krevende - relevant',
 'St.meld. nr. 11 (2001-2002) Kvalitetsreformen Om vurdering av enkelte unntak fra ny gradsstruktur i høyere utdanning',
 'St.meld. nr. 32 (2000-2001) Evaluering av faget Kristendomskunnskap med religions- og livssynsorientering',
 'St.meld. nr. 27 (2000-2001) Gjør din plikt - Krev din rett',
 'St.meld. nr. 20 (2000-2001) Om korte yrkesrettede utdanninger etter videregående opplæring',
 'St.meld. nr. 21 (2000-2001) Styrt val i 4. studieåret i allmennlærarutdanninga',
 'St.meld. nr. 27 (1999-2000) Barnehage til beste for barn og foreldre',
 'St.meld. nr. 12 (1999-2000) ... og yrke skal båten bera ...',
 'Meld. St. 55 (1996–1997) Om skolefritidsordningen',
 'St.meld nr 22 (1996–97) Om lærlingsituasjonen',
 'Meld. St. 14 (1995–1996) Om kristendomskunnskap med religions- og livssynsorientering']

# %%
editions = [x.split()[:4] for x in stm]

# %%
import pandas as pd

# %%
kudos = pd.read_csv("kudos.csv", index_col = 0)

# %%
keys = [x[2] for x in editions]

# %%
def check(identifier, keys):
    cand = identifier.split()[:4]
    res = False
    if len(cand) > 2:
        if cand[2] in keys :
            res = True
    return res

# %%
kudos.loc[kudos.literaryform.fillna('').str.contains("Melding")].loc[kudos.title.fillna('').apply(lambda x:check(x, keys))]
# Out:
#          dhlabid                            urn  \
# 5      700019960  URN:NBN:no-nb_dhlab_700019960
# 12     700020015  URN:NBN:no-nb_dhlab_700020015
# 38     700022776  URN:NBN:no-nb_dhlab_700022776
# 152    700019660  URN:NBN:no-nb_dhlab_700019660
# 153    700018169  URN:NBN:no-nb_dhlab_700018169
# ...          ...                            ...
# 25296  700018160  URN:NBN:no-nb_dhlab_700018160
# 25393  700020020  URN:NBN:no-nb_dhlab_700020020
# 25445  700021695  URN:NBN:no-nb_dhlab_700021695
# 25463  700019937  URN:NBN:no-nb_dhlab_700019937
# 25465  700017496  URN:NBN:no-nb_dhlab_700017496
#
#                                                    title  authors  oaiid  \
# 5           St.meld. nr. 44 (2008-2009): Utdanningslinja      NaN    NaN
# 12     Meld. St. 11 (2009 – 2010): Samarbeidet med Ru...      NaN    NaN
# 38     St.meld. nr. 41 (2002-2003): Om tariffar for o...      NaN    NaN
# 152    Meld. St. 9 (2010–2011): Fullskala CO2-håndtering      NaN    NaN
# ...
