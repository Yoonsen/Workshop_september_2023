# %%
import dhlab as dh
import pandas as pd

# %%
from collections import Counter

# %%
dh.css()
# Out:
# <style>@import url(http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Shippori+Mincho|Istok+Web|Philosopher|Assistant:200,400,700);
#
# p {
#     font-size:1.3em;
#     font-family:serif;
#     line-height:1.4em;
#     color:#142850;
# }
# h1, h2, h3, h4 {
#     color:#27496d;
# }
#
# /*
# .prompt, .jp-InputPrompt, .jp-InputArea-prompt, .jp-OutputPrompt, .jp-OutputArea-prompt {
#     visibility: hidden;
# }
#
#
# .jp-CodeCell .jp-Notebook-cell    {
#     margin-left:10%;
#     margin-right:5%;
# }
#
#
# .jp-InputArea, .jp-OutputArea {
#     margin-left:2.5em;
#     margin-right:2.5em;
# }
# */
#
#
# body  {
#     margin:10%;
#     counter-reset: h1counter;
#
# }
#
# /* .jp-MarkdownOutput, .text_cell_render {
#
#     background-color:#FEFBF1;
#     border-style: solid;
#     border-width: 1px;
#     border-color: rgba(0,0,0, 0.10);;
# } */
#
#
# h1:after {
#     content: ""; /* This is necessary for the pseudo element to work. */
#     display: block; /* This will put the pseudo element on its own line. */
#     /*margin: 0 auto; This will center the border. */
#     width: 50%; /* Change this to whatever width you want. */
#     padding-top: 10px;
#     border-bottom:3px solid SlateGray; /* FireBrick; */
# }
#
# h2:after {
#     content: ""; /* This is necessary for the pseudo element to work. */
#     display: block; /* This will put the pseudo element on its own line. */
#     /*margin: 0 auto; This will center the border. */
#     width: 30%; /* Change this to whatever width you want. */
#     padding-top: 10px;
#     border-bottom:2px solid SlateGray; /* FireBrick; */
# }
#
# </style>

# %% [markdown]
# Bestilling til DH-lab
#
#
#
# Korpus - Barne- og ungdomslitteratur utgitt i Norge
# Tidsperiode: 1945 til i dag, med mulighet for fortløpende oppdatering
# Materialtype: Alle slags bøker og tegneserier og tidsskrift som er gitt ut for målgruppen barn og unge
# Dette inkluderer blant annet pekebøker, bildebøker, kapittelbøker, barneromaner, ungdomsromaner, lettlestbøker, seriebøker, diktsamlinger, dramatikk, faktabøker, faglitteratur, essays, biografier, leksikon mm Alt som er gitt ut for barn og unge MEN IKKE skolebøker
# Språk: Norsk bokmål, nynorsk, samiske språk, kvensk, skogfinsk, romani, romanes
#
#
#
# Korpus - Dokumenter fra Kulturdepartementet, inkl i samarbeid med andre departement
#
# Kulturdepartementet har hatt ulike navn: Kirke- og kulturdepartementet, Kultur- og likestillingsdepartementet, Kulturdepartementet, Kirke- og undervisningsdepartementet, Kyrkje- og undervisningsdepartementet, Kyrkjedepartementet, Kyrkje- og kulturdepartementet
#
# Tidsperiode: 1945 til i dag, med mulighet for fortløpende oppdatering
# Materialtype: Rapporter, planer og strategier, NOU’er, Stortingsmeldinger, Prop’er
#
# Alle temaer
# Språk: Norsk bokmål, nynorsk
#
#
#
# Korpusene må gjerne inndeles i 10-år da vi ønsker å kunne foreta sammenligninger for å spore utvikling fra tiår til tiår
#
# 1945 – 1949
# 1950 – 1959
#
# 1960 – 1969
#
# 1970 – 1979
#
# 1980 – 1989
#
# 1990 – 1999
#
# 2000 – 2009
#
# 2010 – 2019
#
# 2020 – til i dag, med mulighet for fortløpende oppdatering
#
#
#
# Vi ber om at korpusene utformes slik at vi kan foreta følgende operasjoner
#
# Søke på ord-nivå, ordstamme
# Frekvenstelling, få satt opp frekvenslister for de aktuelle søkeordene
#
# Undersøke frekvens av sammenstillinger (at noen ord vi definerer opptrer i nærheten av hverandre, men også åpne søk/få frem hvorvidt det er sammenstillinger vi ikke har tenkt på)
# Kollokasjoner, se hvilke ord de vi søker på opptrer sammen med
#
# Konkordans, slik at vi kan lese teksten rundt søkeordet, noen setninger før og etter
#
# Metadata, slik at vi bare ved et tastetrykk kan få tilgang til hele det aktuelle dokumentet (få korpuset på excel?)
#
#
#
# Det må også være mulig å søke på bilder.
# Barne- og ungdomslitteraturen er til en stor grad visuell. Kan det som Jørgen Schyberg holder på med; Maken hjelpe oss der?
# Politiske ord som medvirkning, mangfold eller fornorsking vil jo gjerne vises i bilder like mye som tekst.

# %%
kult = dh.Corpus(doctype='kudos', limit = 30000)

# %%
class AnnoCorpus:
    def __init__(self, step=10, limit=30000, **kwargs):
        keywords = kwargs
        keywords['limit'] = limit
        corpus = dict()
        from_year = keywords['from_year']
        to_year = keywords['to_year']
        for year in range(from_year,to_year, step):
            keywords['from_year'] = year
            keywords['to_year'] = year + step
            corpus[year] = dh.Corpus(**keywords).frame[['dhlabid','urn', 'title', 'year', 'ddc', 'genres', 'literaryform','city']]
        self.corpus = corpus

    def corpus_num(self, sequence):
        if sequence in self.corpus.keys():
            res = self.corpus[sequence]
        elif sequence in range(len(self.corpus.keys())):
            res = self.corpus[list(self.corpus.keys())[sequence]]
        else:
            res = pd.DataFrame()
        return res

# %%
a = AnnoCorpus(doctype='digibok', from_year=1945, to_year=2023, step=10, subject="kultur*")

# %%
list(a.corpus.keys())[0]
# Out:
# 1945

# %%
a.corpus_num(20)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
barn = dh.Corpus(doctype="digibok", subject="barn*", from_year = 1945, to_year = 2023,limit=50000)
barn.size
# Out:
# 25661

# %%
counts = pd.DataFrame.from_dict(Counter([x for x in [x for x in [y.strip() for x in barn.frame.subjects for y in x.split('/') ]] if x.startswith('barn') or x.startswith('Barn')]), orient='index', columns=['antall']).sort_values(by='antall', ascending=False)

# %%
counts[counts.antall > 1000]
# Out:
#                  antall
# barn              10497
# barnebøker         7579
# barnehager         1990
# barnelitteratur    1810
# Barn               1567
# barnevern          1284
# barnetrinnet       1057

# %%
kultur
# Out:
#         dhlabid                                  urn  \
# 0     100437125  URN:NBN:no-nb_digibok_2021022548595
# 1     100466671  URN:NBN:no-nb_digibok_2008012204045
# 8993  2003                     Vidarforlagets kulturbibliotek
# 8994  2010                                    Norsk kulturarv
# 8995  1995    Geografisk institutt, Universitetet i Trondheim
# 8996  1992                     Arkeologisk museum i Stavanger
# 8997  2005                            [Marit Elin Kyrkjeeide]
#
#                 langs                                           subjects  \
# 0                 nob  Arbeidere / Arbeiderklasse / Historisk framsti...
# 1                 nob  skolefritidsordninger / heldagsskolen / kultur...
# 2                 nno  Historisk framstilling / Kultur / Etnologi / f...
# 3                 nob  Kunst / Kultur / Politikk / Museer / Kulturpol...
# 4                 nob  Sport / Organisasjoner / kultur / idrett / for...
# ...               ...                                                ...
# 8993              nob  Modernitet / Sosial endring / sosial / endring...
# 8994              nob  Reisehåndbøker / Norge / Overnattingssteder / ...
# 8995              swe  geografi / midt / norden / kulturgeografi / re...
# 8996  mul / dan / nob  Arkeologi / Jernalder / Folkevandringstiden / ...
# 8997              nob  Aged / Nursing Care / Norway / Nepal / Cross-C...
#
#                           ddc    genres   literaryform  doctype ocr_creator  \
# 0                   331.09481      text  Faglitteratur  digibok          nb
# 1                                        Faglitteratur  digibok          nb
# 2     390.094912 / 390.094912            Faglitteratur  digibok          nb
# 3                     708.821            Uklassifisert  digibok          nb
# 4                                        Faglitteratur  digibok          nb
# ...                       ...       ...            ...      ...         ...
# 8993                    303.4            Faglitteratur  digibok          nb
# 8994                 914.8104  handbook  Faglitteratur  digibok          nb
# 8995                                     Uklassifisert  digibok          nb
# 8996                 948.3422            Faglitteratur  digibok          nb
# 8997                610.73071            Faglitteratur  digibok          nb
#
#      ocr_timestamp
# 0         20060101
# 1         20060101
# 2         20060101
# 3         20060101
# 4         20060101
# ...            ...
# 8993      20060101
# 8994      20060101
# 8995      20060101
# 8996      20060101
# 8997      20060101
#
# [8998 rows x 19 columns]

# %%
# Out:
#      dhlabid                                  urn  \
# 0  100602454  URN:NBN:no-nb_digibok_2021121448586
# 1  100208054  URN:NBN:no-nb_digibok_2014060408152
# 2  100454542  URN:NBN:no-nb_digibok_2008012804011
# 3  100245952  URN:NBN:no-nb_digibok_2015042008036
# 4  100530252  URN:NBN:no-nb_digibok_2008091600005
# 5  100597264  URN:NBN:no-nb_digibok_2021063048580
# 6  100457867  URN:NBN:no-nb_digibok_2008020404075
# 7  100447428  URN:NBN:no-nb_digibok_2009020604038
# 8  100632111  URN:NBN:no-nb_digibok_2014060526001
# 9  100021308  URN:NBN:no-nb_digibok_2010110108016
#
#                                                title  \
# 0  Konkurransevridning i statens favør : Kulturde...
# 1          Den Europeiske konvensjon om tilskuervold
# 2  Idrettsanleggregisteret [sic] : rapportering, ...
# 3  Lånte fjører eller bunad? : om norsk skrivemåt...
# 4  Prisverdig! : Kulturdepartementets premiering ...
# 5  Niste på veien : en vandreutstilling med islan...
# 6  Lokale- og regionale kulturbygg : mål og utfor...
# 7  Referat fra Symposium om svømmehaller : Hurdal...
# 5  Skjønnlitteratur  digibok          nb       20060101
# 6     Uklassifisert  digibok          nb       20060101
# 7     Faglitteratur  digibok          nb       20060101
# 8     Uklassifisert  digibok       dhlab       20221209
# 9     Faglitteratur  digibok          nb       20060101

# %%
kult
# Out:
#          dhlabid        urn  \
# 0      700005196  700005196
# 1      700001051  700001051
# 2      700019563  700019563
# 3      700020177  700020177
# 4      700003609  700003609
# ...          ...        ...
# 25529  700025737  700025737
# 25530  700017622  700017622
# 25531  700013053  700013053
# 25532  700012217  700012217
# 25533  700018119  700018119
#
#                                                    title authors oaiid  \
# 0        Predikering av branner og ulykker i vegtunneler
# 1      End Review of Support to the Country Programme...
# 2      Prop. 12 L (2012–2013): Lov om endringer i sjø...
# 3      Prop. 21 S (2010–2011): Endringar i statsbudsj...
# 4                                   Tildelingsbrev (pdf)
# ...                                                  ...     ...   ...
# 25529  Fordelingsvirkninger av bostøtte til alderspen...
# 25530  Prop. 75 L (2019–2020): Midlertidig lov om rek...
# 25531                     Mot ei betre rådgivingsteneste
# 25532                                    Årsrapport 2017
# 25533  Prop. 42 LS (2018–2019): Endringer i straffelo...
#
#       sesamid         isbn10 city            timestamp  year publisher langs  \
# 0              9788248022459       2019-09-10 00:00:00  2019              no
# 1              9788275482110       2009-01-16 00:00:00  2009              en
# 2                                  2012-10-26 11:45:00  2012              no
# 3                                  2010-11-19 11:45:00  2010              nn
# 4                                  2017-01-03 00:00:00  2017              no
# ...       ...            ...  ...                  ...   ...       ...   ...
# 25529                              2011-01-01 00:00:00  2011              no
# 25530                              2020-04-15 11:45:00  2020              no
# 25531                                                                     no
# 25532                              2018-03-22 00:00:00  2018              en
# 25533                              2018-12-20 11:45:00  2018              no
#
#       subjects ddc                      genres    literaryform doctype  \
# 0                                Ukategorisert          Report   kudos
# 1                                Ukategorisert   Norad-rapport   kudos
# 2                   Proposisjon til Stortinget     Proposisjon   kudos
# 3                   Proposisjon til Stortinget     Proposisjon   kudos
# 4                               Tildelingsbrev  Tildelingsbrev   kudos
# ...        ...  ..                         ...             ...     ...
# 25529                            Ukategorisert         rapport   kudos
# 25530               Proposisjon til Stortinget     Proposisjon   kudos
# 25531                            Ukategorisert         Rapport   kudos
# 25532                               Årsrapport      Årsrapport   kudos
# 25533               Proposisjon til Stortinget     Proposisjon   kudos
#
#       ocr_creator        ocr_timestamp
# 0           kudos  2022-10-06 14:08:02
# 1           kudos  2022-10-06 14:08:02
# 2           kudos  2023-02-01 11:35:43
# 3           kudos  2023-02-01 11:48:22
# 4           kudos  2022-06-08 23:23:06
# ...           ...                  ...
# 25529       kudos  2022-12-09 11:00:46
# 25530       kudos  2023-02-01 11:08:09
# 25531       kudos  2022-10-06 11:34:15
# 25532       kudos  2022-06-08 23:11:30
# 25533       kudos  2023-02-01 11:15:07
#
# [25534 rows x 19 columns]

# %%
bul
